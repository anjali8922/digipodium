# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # what you need to learn
# - loading data
# - selection
#    - cols
#    - rows
# - Manipulation
#    - add column
#    - remove column
#    - rename column
#    - change datatpye
#    - delete data
#    - merge
#    - group
#    - pivot
#    - sort
#    - remove duplicates
# - Visualization
#   - lineplot
#   - bar plot
#   - histogram
#   - box plot
#   - scatter plot
#   - pie chart
#   - heat map
#   - word cloud
#   -

# %%
penguins=sns.load_dataset('penguins')
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %% [markdown]
# - Analysis
#   - universal analysis
#   - bi-variate analysis
#   - multi-variate analysis

# %% [markdown]
# - loading data
#   - custome data in variable
#   - excel data
#   - csv/json/etc
#   - database (sql)

# %%
students={
    'name':['anjali','apoorva','vanshika','nainshi','apurva','snchali'],
    'college':['kcnit','delhi','pt.jain','kcnit','kcnit','kcnit'],
    'Dob':['21 march','27 sep','18 july','15 july','30 sep','2 dec']
    }
stf= pd.DataFrame(students)
stf
# Out:
#        name  college       Dob
# 0    anjali    kcnit  21 march
# 1   apoorva    delhi    27 sep
# 2  vanshika  pt.jain   18 july
# 3   nainshi    kcnit   15 july
# 4    apurva    kcnit    30 sep
# 5   snchali    kcnit     2 dec

# %%
data=pd.read_excel('C:/Users/anjal/OneDrive/Desktop/digipodium/example.xlsx')
data
# Out:
#         Item  qyt  amt
# 0      Apple   12  100
# 1     Banana   12  150
# 2       Gova    6   50
# 3     Grapes   50  200
# 4    peanuts  100  200
# 5  jackfruit    1   60

# %%
data.info()  # textual ND NUMBERS CALLES OBJECT IN PYTHON
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Item    6 non-null      object
#  1   qyt     6 non-null      int64
#  2   amt     6 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 276.0+ bytes

# %%
data.columns.tolist()
# Out:
# ['Item', 'qyt', 'amt']

# %%
data['Item'] #column selction as dictonary key
# Out:
# 0        Apple
# 1       Banana
# 2         Gova
# 3       Grapes
# 4      peanuts
# 5    jackfruit
# Name: Item, dtype: object

# %%
data.amt # column selection as  object attribute
# Out:
# 0    100
# 1    150
# 2     50
# 3    200
# 4    200
# 5     60
# Name: amt, dtype: int64

# %%
data[['Item','amt']] #column selction as list of columns
# Out:
#         Item  amt
# 0      Apple  100
# 1     Banana  150
# 2       Gova   50
# 3     Grapes  200
# 4    peanuts  200
# 5  jackfruit   60

# %%
data['amt'] *data['qyt']
# Out:
# 0     1200
# 1     1800
# 2      300
# 3    10000
# 4    20000
# 5       60
# dtype: int64

# %%
data['total']=data['qyt'] * data['amt']
data
# Out:
#         Item  qyt  amt  total
# 0      Apple   12  100   1200
# 1     Banana   12  150   1800
# 2       Gova    6   50    300
# 3     Grapes   50  200  10000
# 4    peanuts  100  200  20000
# 5  jackfruit    1   60     60

# %%
data['crap']='some crap'
data
# Out:
#         Item  qyt  amt  total       crap
# 0      Apple   12  100   1200  some crap
# 1     Banana   12  150   1800  some crap
# 2       Gova    6   50    300  some crap
# 3     Grapes   50  200  10000  some crap
# 4    peanuts  100  200  20000  some crap
# 5  jackfruit    1   60     60  some crap

# %% [markdown]
# ### Removing

# %%
data.drop(columns=['crap'],inplace=True) #inplace=True to change permanent in data frame
data
# Out:
#         Item  qyt  amt  total
# 0      Apple   12  100   1200
# 1     Banana   12  150   1800
# 2       Gova    6   50    300
# 3     Grapes   50  200  10000
# 4    peanuts  100  200  20000
# 5  jackfruit    1   60     60

# %%
data.iloc[0]
# Out:
# Item     Apple
# qyt         12
# amt        100
# total     1200
# Name: 0, dtype: object

# %%
data.iloc[:2]
# Out:
#      Item  qyt  amt  total
# 0   Apple   12  100   1200
# 1  Banana   12  150   1800

# %%
stf
# Out:
#        name  college       Dob
# 0    anjali    kcnit  21 march
# 1   apoorva    delhi    27 sep
# 2  vanshika  pt.jain   18 july
# 3   nainshi    kcnit   15 july
# 4    apurva    kcnit    30 sep
# 5   snchali    kcnit     2 dec

# %%
data['qyt']=data['qyt']-10

# %%
data
# Out:
#         Item  qyt  amt  total
# 0      Apple    2  100   1200
# 1     Banana    2  150   1800
# 2       Gova   -4   50    300
# 3     Grapes   40  200  10000
# 4    peanuts   90  200  20000
# 5  jackfruit   -9   60     60

# %%
data.columns.tolist()
# Out:
# ['Item', 'qyt', 'amt', 'total']

# %%
data.rename(
    mapper={'Item':'Product',
            'qyt':'quantity',
            'amt':'Amount',
            'total':'Expenditrue'},
    axis=1,
    inplace=True        
)
data
# Out:
#      Product  quantity  Amount  Expenditrue
# 0      Apple         2     100         1200
# 1     Banana         2     150         1800
# 2       Gova        -4      50          300
# 3     Grapes        40     200        10000
# 4    peanuts        90     200        20000
# 5  jackfruit        -9      60           60

# %% [markdown]
# - OPERATION
#   - Delete data
#     - columns
#     - indexes
#   - Remove duplicates
#   - sort
#   - Group
#   - Pivot
#   - Merge

# %%
penguins.columns.tolist()
# Out:
# ['species',
#  'island',
#  'bill_length_mm',
#  'bill_depth_mm',
#  'flipper_length_mm',
#  'body_mass_g',
#  'sex']

# %%
penguins.drop(columns='body_mass_g')
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#         sex
# 0      Male
# 1    Female
# 2    Female
# 3       NaN
# 4    Female
# ...

# %%
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
#penguins.drop(columns='body_mass_g',inplace=True) #use of inplace remove for always the data

# %%
#penguins

# %%
penguins.drop(columns=['island','sex'])
# Out:
#     species  bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# 0    Adelie            39.1           18.7              181.0       3750.0
# 1    Adelie            39.5           17.4              186.0       3800.0
# 2    Adelie            40.3           18.0              195.0       3250.0
# 3    Adelie             NaN            NaN                NaN          NaN
# 4    Adelie            36.7           19.3              193.0       3450.0
# ..      ...             ...            ...                ...          ...
# 339  Gentoo             NaN            NaN                NaN          NaN
# 340  Gentoo            46.8           14.3              215.0       4850.0
# 341  Gentoo            50.4           15.7              222.0       5750.0
# 342  Gentoo            45.2           14.8              212.0       5200.0
# 343  Gentoo            49.9           16.1              213.0       5400.0
#
# [344 rows x 5 columns]

# %%
#penguins.drop(columns=[0,1,2,3])  #Eror

# %%
penguins.drop(index=2) #drop row 3rd
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
penguins.drop(index=[0,1,2,3]) #drop row 0 to 3
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# 6    Adelie  Torgersen            38.9           17.8              181.0
# 7    Adelie  Torgersen            39.2           19.6              195.0
# 8    Adelie  Torgersen            34.1           18.1              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 4         3450.0  Female
# 5         3650.0    Male
# ...

# %%
penguins.drop(index=range(9)) # drop row 0 to 8 (drop multiple line using range)
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 9    Adelie  Torgersen            42.0           20.2              190.0
# 10   Adelie  Torgersen            37.8           17.1              186.0
# 11   Adelie  Torgersen            37.8           17.3              180.0
# 12   Adelie  Torgersen            41.1           17.6              182.0
# 13   Adelie  Torgersen            38.6           21.2              191.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 9         4250.0     NaN
# 10        3300.0     NaN
# ...

# %%
np.nan
# Out:
# nan

# %% [markdown]
# # find out the missing data of values in each columns

# %%
penguins.isnull() #tells that where the missing data showing True
# Out:
#      species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0      False   False           False          False              False
# 1      False   False           False          False              False
# 2      False   False           False          False              False
# 3      False   False            True           True               True
# 4      False   False           False          False              False
# ..       ...     ...             ...            ...                ...
# 339    False   False            True           True               True
# 340    False   False           False          False              False
# 341    False   False           False          False              False
# 342    False   False           False          False              False
# 343    False   False           False          False              False
#
#      body_mass_g    sex
# 0          False  False
# 1          False  False
# 2          False  False
# ...

# %%
penguins.isnull().sum() # total of all null columns
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64

# %%
sns.heatmap(penguins.isnull(),cbar=True) #overall null value visualization
# Out:
# <Axes: >

# %%
penguins.isnull().sum().plot(kind='bar') #column wise null value visualization
# Out:
# <Axes: >

# %% [markdown]
# # removing the missing values(nan values ,nan=not a number)

# %%
penguins.dropna() #drop rows with null values
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
penguins.shape
# Out:
# (344, 7)

# %%
penguins.dropna().shape
# Out:
# (333, 7)

# %%
penguins.dropna(inplace=True)
print(penguins.shape)
# Out:
# (333, 7)

# %%
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
penguins.drop_duplicates(subset=['species']) #example
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7              181.0
# 152  Chinstrap      Dream            46.5           17.9              192.0
# 220     Gentoo     Biscoe            46.1           13.2              211.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 152       3500.0  Female
# 220       4500.0  Female

# %% [markdown]
# # - Sorting

# %%
penguins.sort_values(by='sex')
# Out:
#        species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 172  Chinstrap   Dream            42.4           17.3              181.0
# 136     Adelie   Dream            35.6           17.5              191.0
# 138     Adelie   Dream            37.0           16.5              185.0
# 272     Gentoo  Biscoe            45.1           14.4              210.0
# 140     Adelie   Dream            40.2           17.1              193.0
# ..         ...     ...             ...            ...                ...
# 163  Chinstrap   Dream            51.7           20.3              194.0
# 165  Chinstrap   Dream            52.0           18.1              201.0
# 167  Chinstrap   Dream            50.5           19.6              201.0
# 145     Adelie   Dream            39.0           18.7              185.0
# 343     Gentoo  Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 172       3600.0  Female
# 136       3175.0  Female
# ...

# %%
penguins.sort_values(by=['sex','island'],ascending=False)
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# 7    Adelie  Torgersen            39.2           19.6              195.0
# 13   Adelie  Torgersen            38.6           21.2              191.0
# 14   Adelie  Torgersen            34.6           21.1              198.0
# ..      ...        ...             ...            ...                ...
# 332  Gentoo     Biscoe            43.5           15.2              213.0
# 334  Gentoo     Biscoe            46.2           14.1              217.0
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 5         3650.0    Male
# ...

# %%
penguins.sort_values(by=['sex','island']) #ascending=True defalut value
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 20   Adelie     Biscoe            37.8           18.3              174.0
# 22   Adelie     Biscoe            35.9           19.2              189.0
# 25   Adelie     Biscoe            35.3           18.9              187.0
# 27   Adelie     Biscoe            40.5           17.9              187.0
# 28   Adelie     Biscoe            37.9           18.6              172.0
# ..      ...        ...             ...            ...                ...
# 123  Adelie  Torgersen            41.4           18.5              202.0
# 125  Adelie  Torgersen            40.6           19.0              199.0
# 127  Adelie  Torgersen            41.5           18.3              195.0
# 129  Adelie  Torgersen            44.1           18.0              210.0
# 131  Adelie  Torgersen            43.1           19.2              197.0
#
#      body_mass_g     sex
# 20        3400.0  Female
# 22        3800.0  Female
# ...

# %% [markdown]
# - Data type in pandas
#  - int
#  - float
#  - boolean
#  - string(not understood by pandas ,unless you specify)
#  - datetime
#  - category
#  - onject(if datatpe is not understood by pandas than object is used)

# %%
penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 333 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            333 non-null    object
#  1   island             333 non-null    object
#  2   bill_length_mm     333 non-null    float64
#  3   bill_depth_mm      333 non-null    float64
#  4   flipper_length_mm  333 non-null    float64
#  5   body_mass_g        333 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 20.8+ KB

# %%
penguins.dtypes
# Out:
# species               object
# island                object
# bill_length_mm       float64
# bill_depth_mm        float64
# flipper_length_mm    float64
# body_mass_g          float64
# sex                   object
# dtype: object

# %%
penguins.select_dtypes(include='number')
# Out:
#      bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# 0              39.1           18.7              181.0       3750.0
# 1              39.5           17.4              186.0       3800.0
# 2              40.3           18.0              195.0       3250.0
# 4              36.7           19.3              193.0       3450.0
# 5              39.3           20.6              190.0       3650.0
# ..              ...            ...                ...          ...
# 338            47.2           13.7              214.0       4925.0
# 340            46.8           14.3              215.0       4850.0
# 341            50.4           15.7              222.0       5750.0
# 342            45.2           14.8              212.0       5200.0
# 343            49.9           16.1              213.0       5400.0
#
# [333 rows x 4 columns]

# %%
penguins.select_dtypes(include='object')
# Out:
#     species     island     sex
# 0    Adelie  Torgersen    Male
# 1    Adelie  Torgersen  Female
# 2    Adelie  Torgersen  Female
# 4    Adelie  Torgersen  Female
# 5    Adelie  Torgersen    Male
# ..      ...        ...     ...
# 338  Gentoo     Biscoe  Female
# 340  Gentoo     Biscoe  Female
# 341  Gentoo     Biscoe    Male
# 342  Gentoo     Biscoe  Female
# 343  Gentoo     Biscoe    Male
#
# [333 rows x 3 columns]

# %%
penguins.select_dtypes(exclude='number') #excluding that mention part and print all datatype
# Out:
#     species     island     sex
# 0    Adelie  Torgersen    Male
# 1    Adelie  Torgersen  Female
# 2    Adelie  Torgersen  Female
# 4    Adelie  Torgersen  Female
# 5    Adelie  Torgersen    Male
# ..      ...        ...     ...
# 338  Gentoo     Biscoe  Female
# 340  Gentoo     Biscoe  Female
# 341  Gentoo     Biscoe    Male
# 342  Gentoo     Biscoe  Female
# 343  Gentoo     Biscoe    Male
#
# [333 rows x 3 columns]

# %% [markdown]
# # change the data type

# %%
penguins['island'].astype('category') #not actually applied on the column
# Out:
# 0      Torgersen
# 1      Torgersen
# 2      Torgersen
# 4      Torgersen
# 5      Torgersen
#          ...
# 338       Biscoe
# 340       Biscoe
# 341       Biscoe
# 342       Biscoe
# 343       Biscoe
# Name: island, Length: 333, dtype: category
# Categories (3, object): ['Biscoe', 'Dream', 'Torgersen']

# %%
penguins['island']=  penguins['island'].astype('category') #casting object to category

# %%
penguins.dtypes
# Out:
# species                object
# island               category
# bill_length_mm        float64
# bill_depth_mm         float64
# flipper_length_mm     float64
# body_mass_g           float64
# sex                    object
# dtype: object

# %%
penguins.sex=penguins.sex.astype('bool')
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 4  Adelie  Torgersen            36.7           19.3              193.0
# 5  Adelie  Torgersen            39.3           20.6              190.0
#
#    body_mass_g   sex
# 0       3750.0  True
# 1       3800.0  True
# 2       3250.0  True
# 4       3450.0  True
# 5       3650.0  True

# %% [markdown]
# # simple visualization(univariate)
# - For numerical data
#    - Line plot -> `.plot()`
#    - bar plot ->`.plot(kind='bar')`
#    - histogram -> `.hist()`
#    - box plot -> `.plot(kind='box)`
#    - area plot -> `.plot(kind='area)`
# - For categoricl data
#   -  bar plot ->`.plot(kind='bar')`
#   - pie chart ->`.plot(kind='pie')`

# %%
penguins['bill_depth_mm'].hist(figsize=(4,2))
# Out:
# <Axes: >

# %%
penguins['bill_depth_mm'].plot(figsize=(4,2))
# Out:
# <Axes: >

# %%
penguins['bill_depth_mm'].plot(kind='area',figsize=(5,2))
# Out:
# <Axes: >

# %%
penguins['bill_depth_mm'].plot(kind='bar',figsize=(4,2))
# Out:
# <Axes: >

# %%
penguins['bill_depth_mm'].plot(kind='box',vert=False,figsize=(5,4))
# Out:
# <Axes: >

# %%
penguins['bill_depth_mm'].plot(kind='box',figsize=(5,4))
# Out:
# <Axes: >

# %% [markdown]
# # Comparing  univariate data in a single graph

# %%
penguins.columns
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %%
penguins[['bill_depth_mm','bill_length_mm']]
# Out:
#      bill_depth_mm  bill_length_mm
# 0             18.7            39.1
# 1             17.4            39.5
# 2             18.0            40.3
# 4             19.3            36.7
# 5             20.6            39.3
# ..             ...             ...
# 338           13.7            47.2
# 340           14.3            46.8
# 341           15.7            50.4
# 342           14.8            45.2
# 343           16.1            49.9
#
# [333 rows x 2 columns]

# %%
penguins[['bill_depth_mm','bill_length_mm']].plot(figsize=(5,3))
# Out:
# <Axes: >

# %%
penguins[['bill_depth_mm','bill_length_mm']].plot(kind='box',figsize=(5,3))
# Out:
# <Axes: >

# %%
penguins[['bill_depth_mm','bill_length_mm']].hist(bins=70,figsize=(5,3))
# Out:
# array([[<Axes: title={'center': 'bill_depth_mm'}>,
#         <Axes: title={'center': 'bill_length_mm'}>]], dtype=object)

# %% [markdown]
# Putting columns visualization in subplots

# %%
penguins[['bill_depth_mm','bill_length_mm']].plot(layout= (1,2),subplots=True,figsize=(10,5))
# Out:
# array([[<Axes: >, <Axes: >]], dtype=object)

# %%
penguins['island'].value_counts()
# Out:
# island
# Biscoe       163
# Dream        123
# Torgersen     47
# Name: count, dtype: int64

# %%
penguins['island'].value_counts().plot(kind='bar',figsize=(5,3))
# Out:
# <Axes: xlabel='island'>

# %%
penguins['island'].value_counts().plot(kind='pie',figsize=(5,3))
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # power of seaborn for better visualization

# %%
sns.displot(data=penguins,x='bill_depth_mm',hue='island')

# %%
sns.displot(data=penguins,x='body_mass_g',hue='island')

# %%
sns.countplot(data=penguins,x='island')
# Out:
# <Axes: xlabel='island', ylabel='count'>

# %%
sns.countplot(data=penguins,x='island',hue='species')
# Out:
# <Axes: xlabel='island', ylabel='count'>

# %%
sns.barplot(data=penguins,x='island',y='bill_depth_mm')
# Out:
# <Axes: xlabel='island', ylabel='bill_depth_mm'>

# %% [markdown]
# # bivariate analysis
# - scatter plot(numeric vs numeric)
# - violin plot(aternative to box plot)
# - pair plot

# %%
sns.scatterplot(data=penguins,x='bill_depth_mm',y='bill_length_mm')
# Out:
# <Axes: xlabel='bill_depth_mm', ylabel='bill_length_mm'>

# %%
sns.scatterplot(data=penguins,x='bill_depth_mm',y='bill_length_mm',hue='species')
# Out:
# <Axes: xlabel='bill_depth_mm', ylabel='bill_length_mm'>

# %%
sns.scatterplot(data=penguins,x='bill_depth_mm',y='bill_length_mm',hue='island')
# Out:
# <Axes: xlabel='bill_depth_mm', ylabel='bill_length_mm'>

# %%
sns.color_palette('rainbow')
# Out:
# [(0.21764705882352942, 0.42912060877260894, 0.9755119679804366),
#  (0.0725490196078431, 0.7829276104921027, 0.9005867023006374),
#  (0.3549019607843137, 0.9741386021045101, 0.7829276104921028),
#  (0.6450980392156862, 0.9741386021045102, 0.622112816721474),
#  (0.9274509803921569, 0.7829276104921029, 0.43467642176596505),
#  (1.0, 0.42912060877260916, 0.2199463578396687)]

# %%
sns.set_palette('RdBu')

# %%
sns.scatterplot(data=penguins,x='bill_depth_mm',y='bill_length_mm',hue='species')
# Out:
# <Axes: xlabel='bill_depth_mm', ylabel='bill_length_mm'>

# %%
sns.set_palette('cool')

# %%
sns.scatterplot(data=penguins,x='bill_depth_mm',y='bill_length_mm',hue='species')
# Out:
# <Axes: xlabel='bill_depth_mm', ylabel='bill_length_mm'>

# %%
sns.set_palette('rainbow_r')

# %%
sns.scatterplot(data=penguins,x='bill_depth_mm',y='bill_length_mm',hue='species')
# Out:
# <Axes: xlabel='bill_depth_mm', ylabel='bill_length_mm'>

# %%
sns.scatterplot(data=penguins,x='bill_depth_mm',y='bill_length_mm',hue='species',palette='hot')
# Out:
# <Axes: xlabel='bill_depth_mm', ylabel='bill_length_mm'>

# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
#data = pd.read_csv("city_day.csv")
#data.head(10)
